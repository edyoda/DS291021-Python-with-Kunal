# %%
import module1

# %%
module1.addition(1,2)
# Out:
# 3

# %%
quiz 5 qun 10,5,3


sir how to slove problms in hackerank

# %%
import modul21 as m

# %%
modul21.pi
# Out:
# 3.14

# %%
m.pi
# Out:
# 3.14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
contry_counter = {}
def addone(contry):
    if contry in contry_counter:
        contry_counter[contry]+= 1
    else:
        contry_counter[contry] = 1
addone('China')
addone('japan')
addone('china')

# %%
contry_counter
# Out:
# {'China': 1, 'japan': 1, 'china': 1}

# %%
len(contry_counter)
# Out:
# 3

# %%
s = {'a', 'b', 'c'}

# %%
s1 = set(['a', 'b', 'c'])

# %%
s1.pop()
# Out:
# 'c'

# %%
s
# Out:
# {'a', 'b', 'c'}

# %%
s = {('a', 'b', 'c'),1}

# %%
type(s)
# Out:
# set

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {('a', 'b', 'c')}

# %%
ord('z')
# Out:
# 122

# %%
{'a':97,... ,'z':122} < -- end result

# %%
d = {}
for i in range(ord('a'),ord('z')+1):
    d[chr(i)] = i

# %%
d
# Out:
# {'a': 97,
#  'b': 98,
#  'c': 99,
#  'd': 100,
#  'e': 101,
#  'f': 102,
#  'g': 103,
#  'h': 104,
#  'i': 105,
#  'j': 106,
#  'k': 107,
#  'l': 108,
#  'm': 109,
#  'n': 110,
#  'o': 111,
#  'p': 112,
#  'q': 113,
#  'r': 114,
#  's': 115,
#  't': 116,
#  'u': 117,
#  'v': 118,
#  'w': 119,
#  'x': 120,
#  'y': 121,
#  'z': 122}

# %%
d2 = {chr(i): i for i in range(ord('a'),ord('z')+1)}

# %%
print(d2)
# Out:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101, 'f': 102, 'g': 103, 'h': 104, 'i': 105, 'j': 106, 'k': 107, 'l': 108, 'm': 109, 'n': 110, 'o': 111, 'p': 112, 'q': 113, 'r': 114, 's': 115, 't': 116, 'u': 117, 'v': 118, 'w': 119, 'x': 120, 'y': 121, 'z': 122}
